# %% [markdown]
# <a href="https://colab.research.google.com/github/Sheetal-R/Melanoma_detection_assignment/blob/main/Skin_cancer_ISIC_The_International_Skin_Imaging_Collaboration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problem statement:** To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution that can evaluate images and alert dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.</br>
#
# **Project Pipeline**
# - Data Reading/Data Understanding → Defining the path for train and test images
# - Dataset Creation→ Create train & validation dataset from the train directory with a batch size of 32. Also, make sure you resize your images to 180*180.
# - Dataset visualisation → Create a code to visualize one instance of all the nine classes present in the dataset
# - Model Building & training :
#   - Create a CNN model, which can accurately detect 9 classes present in the dataset. While building the model, rescale images to normalize pixel values between (0,1).
#   - Choose an appropriate optimiser and loss function for model training
#   - Train the model for ~20 epochs
#   - Write your findings after the model fit. You must check if there is any evidence of model overfit or underfit.
# - Chose an appropriate data augmentation strategy to resolve underfitting/overfitting
# - Model Building & training on the augmented data :
#   - Create a CNN model, which can accurately detect 9 classes present in the dataset. While building the model rescale images to normalize pixel values between (0,1).
#   - Choose an appropriate optimiser and loss function for model training
#   - Train the model for ~20 epochs
#   - Write your findings after the model fit, see if the earlier issue is resolved or not?
# - Class distribution: Examine the current class distribution in the training dataset
#   - Which class has the least number of samples?
#   - Which classes dominate the data in terms of the proportionate number of samples?
# - Handling class imbalances: Rectify class imbalances present in the training dataset with Augmentor library.
# - Model Building & training on the rectified class imbalance data :
#   - Create a CNN model, which can accurately detect 9 classes present in the dataset. While building the model, rescale images to normalize pixel values between (0,1).
#   - Choose an appropriate optimiser and loss function for model training
#   - Train the model for ~30 epochs
#   - Write your findings after the model fit, see if the issues are resolved or not?

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Jul 11 06:21:44 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    23W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install -q keras

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from google.colab import drive
from glob import  glob

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
# Create dataframes
train_df = pd.DataFrame(columns=['image_path', 'label'])
test_df = pd.DataFrame(columns=['image_path', 'label'])

# %%
# Add images paths and labels to dataframes

def appendDictToDF(df,dictToAppend):
  df = pd.concat([df, pd.DataFrame.from_records([dictToAppend])])
  return df


for label, directory in enumerate(os.listdir(data_dir_train)):
    for filename in os.listdir(os.path.join(data_dir_train, directory)):
        image_path = os.path.join(data_dir_train, directory, filename)
        #train_df = train_df.append({'image_path': image_path, 'label': label}, ignore_index=True)
        train_df = appendDictToDF(train_df,{'image_path': image_path, 'label': label})


for label, directory in enumerate(os.listdir(data_dir_test)):
    for filename in os.listdir(os.path.join(data_dir_test, directory)):
        image_path = os.path.join(data_dir_test, directory, filename)
        test_df = appendDictToDF(test_df,{'image_path': image_path, 'label': label})

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (2239, 2)
# (118, 2)

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %%
# Get list of directories in train_dir
labels = os.listdir(data_dir_train)

# Create label_map dictionary
label_map = {i: label for i, label in enumerate(labels)}
num_classes=len(label_map)
label_map
# Out:
# {0: 'actinic keratosis',
#  1: 'nevus',
#  2: 'seborrheic keratosis',
#  3: 'dermatofibroma',
#  4: 'pigmented benign keratosis',
#  5: 'vascular lesion',
#  6: 'squamous cell carcinoma',
#  7: 'basal cell carcinoma',
#  8: 'melanoma'}

# %%
# Count the number of images in each class
class_counts = train_df['label'].value_counts().sort_index()

# Print the number of images in each class
print("Dataset Summary")
print("-" * 60)
print(f"{'Class Label':<15} {'Class Name':<30} {'Count':<10}")
print("-" * 60)
for class_label, class_name in label_map.items():
    count = class_counts[class_label]
    print(f"{class_label:<15} {class_name:<30} {count:<10}")
print("-" * 60)
print(f"{'Total':<45} {sum(class_counts):<10}")
# Out:
# Dataset Summary
# ------------------------------------------------------------
# Class Label     Class Name                     Count
# ------------------------------------------------------------
# 0               actinic keratosis              114
# 1               nevus                          357
# 2               seborrheic keratosis           77
# 3               dermatofibroma                 95
# 4               pigmented benign keratosis     462
# 5               vascular lesion                139
# 6               squamous cell carcinoma        181
# 7               basal cell carcinoma           376
# 8               melanoma                       438
# ------------------------------------------------------------
# Total                                         2239

# %% [markdown]
# Found 2239 files belonging to 9 classes.

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_test,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 118 files belonging to 9 classes.
# Using 23 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(3):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
num_classes = 9 # as target class has 9 labels
model = tf.keras.Sequential([
  layers.experimental.preprocessing.Rescaling(1.0/255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.build(input_shape=(None,180,180,3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 217s 87ms/step - loss: 1.9428 - accuracy: 0.3198 - val_loss: 2.7412 - val_accuracy: 0.2174
# Epoch 2/20
# 56/56 [==============================] - 1s 10ms/step - loss: 1.6013 - accuracy: 0.4392 - val_loss: 2.3193 - val_accuracy: 0.2609
# Epoch 3/20
# 56/56 [==============================] - 1s 10ms/step - loss: 1.4388 - accuracy: 0.5006 - val_loss: 2.4317 - val_accuracy: 0.2609
# Epoch 4/20
# 56/56 [==============================] - 1s 10ms/step - loss: 1.3320 - accuracy: 0.5374 - val_loss: 2.5839 - val_accuracy: 0.2609
# Epoch 5/20
# 56/56 [==============================] - 1s 10ms/step - loss: 1.3074 - accuracy: 0.5435 - val_loss: 2.6704 - val_accuracy: 0.2174
# Epoch 6/20
# 56/56 [==============================] - 1s 10ms/step - loss: 1.2054 - accuracy: 0.5675 - val_loss: 3.5034 - val_accuracy: 0.2174
# Epoch 7/20
# 56/56 [==============================] - 1s 10ms/step - loss: 1.1682 - accuracy: 0.5932 - val_loss: 4.4363 - val_accuracy: 0.2174
# Epoch 8/20
# 56/56 [==============================] - 1s 10ms/step - loss: 1.0445 - accuracy: 0.6362 - val_loss: 4.2745 - val_accuracy: 0.2174
# Epoch 9/20
# 56/56 [==============================] - 1s 10ms/step - loss: 0.9633 - accuracy: 0.6641 - val_loss: 3.6054 - val_accuracy: 0.2174
# Epoch 10/20
# 56/56 [==============================] - 1s 10ms/step - loss: 0.9058 - accuracy: 0.6808 - val_loss: 4.1031 - val_accuracy: 0.1739
# Epoch 11/20
# 56/56 [==============================] - 1s 10ms/step - loss: 0.8303 - accuracy: 0.7031 - val_loss: 4.7825 - val_accuracy: 0.1739
# Epoch 12/20
# 56/56 [==============================] - 1s 10ms/step - loss: 0.7656 - accuracy: 0.7243 - val_loss: 4.7300 - val_accuracy: 0.2174
# Epoch 13/20
# 56/56 [==============================] - 1s 10ms/step - loss: 0.7493 - accuracy: 0.7411 - val_loss: 4.0673 - val_accuracy: 0.1739
# Epoch 14/20
# 56/56 [==============================] - 1s 10ms/step - loss: 0.6020 - accuracy: 0.7812 - val_loss: 4.5104 - val_accuracy: 0.1739
# Epoch 15/20
# 56/56 [==============================] - 1s 10ms/step - loss: 0.5604 - accuracy: 0.8052 - val_loss: 6.0927 - val_accuracy: 0.2174
# Epoch 16/20
# 56/56 [==============================] - 1s 10ms/step - loss: 0.5159 - accuracy: 0.8080 - val_loss: 4.8169 - val_accuracy: 0.1739
# Epoch 17/20
# 56/56 [==============================] - 1s 10ms/step - loss: 0.5133 - accuracy: 0.8114 - val_loss: 5.5148 - val_accuracy: 0.2609
# Epoch 18/20
# 56/56 [==============================] - 1s 10ms/step - loss: 0.4286 - accuracy: 0.8454 - val_loss: 4.9478 - val_accuracy: 0.2174
# Epoch 19/20
# 56/56 [==============================] - 1s 10ms/step - loss: 0.3475 - accuracy: 0.8672 - val_loss: 5.4596 - val_accuracy: 0.2174
# Epoch 20/20
# 56/56 [==============================] - 1s 10ms/step - loss: 0.3505 - accuracy: 0.8689 - val_loss: 7.4946 - val_accuracy: 0.2174

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy.
# Your code goes here
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical",input_shape=(img_height, img_width, 3)),
  layers.experimental.preprocessing.RandomRotation(0.2),
  layers.experimental.preprocessing.RandomZoom(0.1),
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(3):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
model = tf.keras.Sequential([
  layers.experimental.preprocessing.Rescaling(1.0/255),
  layers.Conv2D(16, (3, 3), activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Conv2D(32, (3, 3), activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Conv2D(64, (3, 3), activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.build(input_shape=(None,180,180,3))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 178, 178, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 89, 89, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 87, 87, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 43, 43, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 41, 41, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 20, 20, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 20, 20, 64)        0
#
#  flatten_1 (Flatten)         (None, 25600)             0
#
#  dense_2 (Dense)             (None, 128)               3276928
#
#  dense_3 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,301,673
# Trainable params: 3,301,673
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
history = model.fit(
  train_ds,
  batch_size=batch_size,
  validation_data=val_ds, epochs=epochs)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 3s 15ms/step - loss: 2.1584 - accuracy: 0.1747 - val_loss: 2.2299 - val_accuracy: 0.1739
# Epoch 2/20
# 56/56 [==============================] - 1s 12ms/step - loss: 1.9857 - accuracy: 0.2472 - val_loss: 2.2986 - val_accuracy: 0.2174
# Epoch 3/20
# 56/56 [==============================] - 1s 12ms/step - loss: 1.8655 - accuracy: 0.3058 - val_loss: 2.2504 - val_accuracy: 0.2174
# Epoch 4/20
# 56/56 [==============================] - 1s 12ms/step - loss: 1.7473 - accuracy: 0.3694 - val_loss: 2.3125 - val_accuracy: 0.1739
# Epoch 5/20
# 56/56 [==============================] - 1s 12ms/step - loss: 1.5876 - accuracy: 0.4386 - val_loss: 2.3504 - val_accuracy: 0.3043
# Epoch 6/20
# 56/56 [==============================] - 1s 12ms/step - loss: 1.5113 - accuracy: 0.4648 - val_loss: 2.6795 - val_accuracy: 0.1739
# Epoch 7/20
# 56/56 [==============================] - 1s 12ms/step - loss: 1.3992 - accuracy: 0.5145 - val_loss: 2.8564 - val_accuracy: 0.2174
# Epoch 8/20
# 56/56 [==============================] - 1s 12ms/step - loss: 1.3168 - accuracy: 0.5391 - val_loss: 3.0708 - val_accuracy: 0.2174
# Epoch 9/20
# 56/56 [==============================] - 1s 12ms/step - loss: 1.2711 - accuracy: 0.5469 - val_loss: 2.4016 - val_accuracy: 0.2609
# Epoch 10/20
# 56/56 [==============================] - 1s 12ms/step - loss: 1.1959 - accuracy: 0.5954 - val_loss: 2.4485 - val_accuracy: 0.2174
# Epoch 11/20
# 56/56 [==============================] - 1s 12ms/step - loss: 1.1526 - accuracy: 0.5876 - val_loss: 3.4572 - val_accuracy: 0.2174
# Epoch 12/20
# 56/56 [==============================] - 1s 12ms/step - loss: 1.1456 - accuracy: 0.5854 - val_loss: 3.2398 - val_accuracy: 0.2609
# Epoch 13/20
# 56/56 [==============================] - 1s 12ms/step - loss: 1.0551 - accuracy: 0.6189 - val_loss: 2.9423 - val_accuracy: 0.2609
# Epoch 14/20
# 56/56 [==============================] - 1s 12ms/step - loss: 1.0339 - accuracy: 0.6350 - val_loss: 3.5113 - val_accuracy: 0.1739
# Epoch 15/20
# 56/56 [==============================] - 1s 12ms/step - loss: 0.9682 - accuracy: 0.6669 - val_loss: 3.2316 - val_accuracy: 0.2174
# Epoch 16/20
# 56/56 [==============================] - 1s 12ms/step - loss: 0.8782 - accuracy: 0.6908 - val_loss: 3.1124 - val_accuracy: 0.2174
# Epoch 17/20
# 56/56 [==============================] - 1s 12ms/step - loss: 0.8677 - accuracy: 0.6908 - val_loss: 3.5161 - val_accuracy: 0.1739
# Epoch 18/20
# 56/56 [==============================] - 1s 12ms/step - loss: 0.7953 - accuracy: 0.7104 - val_loss: 4.0376 - val_accuracy: 0.2174
# Epoch 19/20
# 56/56 [==============================] - 1s 12ms/step - loss: 0.7624 - accuracy: 0.7249 - val_loss: 4.3515 - val_accuracy: 0.1739
# Epoch 20/20
# 56/56 [==============================] - 1s 12ms/step - loss: 0.6944 - accuracy: 0.7444 - val_loss: 4.8019 - val_accuracy: 0.1739

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
labels = {0 : "actinic", 1: "basel", 2: "dermatofibroma", 3: "melanoma", 4: "nevus",
          5: "pigmented", 6: "seborrheic", 7: "squamous", 8: "vascular"}

def get_classes_distribution(data):
    # Get the count for each label
    label_counts = data['label'].value_counts()

    # Get total number of samples
    total_samples = len(data)


    # Count the number of items in each class
    for i in range(len(label_counts)):
        label = labels[label_counts.index[i]]
        count = label_counts.values[i]
        percent = (count / total_samples) * 100
        print("{:<20s}:   {} or {}%".format(label, count, percent))

# %%
get_classes_distribution(train_df)
# Out:
# nevus               :   462 or 20.634211701652525%
# vascular            :   438 or 19.56230460026798%
# squamous            :   376 or 16.793211255024566%
# basel               :   357 or 15.944618133095132%
# seborrheic          :   181 or 8.083966056275123%
# pigmented           :   139 or 6.208128628852166%
# actinic             :   114 or 5.091558731576597%
# melanoma            :   95 or 4.242965609647164%
# dermatofibroma      :   77 or 3.439035283608754%

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (8.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.65.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.22.4)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F4035432AA0>: 100%|██████████| 500/500 [00:09<00:00, 51.94 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F40353DC310>: 100%|██████████| 500/500 [00:12<00:00, 39.62 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F40354CE1A0>: 100%|██████████| 500/500 [00:10<00:00, 46.35 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F403DC8FA60>: 100%|██████████| 500/500 [00:54<00:00,  9.16 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=919x802 at 0x7F403556F730>: 100%|██████████| 500/500 [00:41<00:00, 11.96 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F40378BF100>: 100%|██████████| 500/500 [00:10<00:00, 49.45 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F4035224BE0>: 100%|██████████| 500/500 [00:21<00:00, 22.75 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F403556F7C0>: 100%|██████████| 500/500 [00:09<00:00, 53.10 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F4035372950>: 100%|██████████| 500/500 [00:09<00:00, 50.50 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list_new
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026650.jpg_c03dc9eb-3392-4946-86c9-f4b20f4423ec.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031381.jpg_f1e79c12-a76e-445a-9296-7ea6da0273fa.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026457.jpg_a1ccb0d1-4573-4f74-b643-180f992337fa.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026702.jpg_a88fd912-abcf-46d9-b991-bb216fb45e7a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027254.jpg_f71645e1-4748-4a91-9464-9e83e86114be.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025780.jpg_2d82103a-2cb0-4ca2-be21-310b01b5019f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031335.jpg_552a3f7e-4b60-4beb-85aa-524034c6c957.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029840.jpg_312a4fba-ec3c-4c86-bdd7-3ef8427cc381.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033456.jpg_00b24b0b-d513-4dea-9051-3a90925a9823.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031430.jpg_6b435181-70da-491b-a9f1-439c2ae0639b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029713.jpg_e71572b3-ffa1-493d-8441-8d8d67679099.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031108.jpg_88a1bb3b-bd8c-4428-85a7-9f0948039fbc.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028517.jpg_64e632f9-7f6e-4edd-9ec0-b6a466c739f4.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026709.jpg_6b481b6f-8178-49a0-8920-fed0adb337df.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030877.jpg_876a3947-1b80-41fb-825c-4a98cb364abe.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032199.jpg_8863d609-d579-4bac-85b8-c4051b6e65d4.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030586.jpg_2dd8abcb-39e4-40ed-b5e5-0335a191b65e.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027829.jpg_6aa8c6ab-0994-48ef-941e-66a70ca28da2.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029900.jpg_d7822548-092e-4129-bdc4-04461a76d652.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029713.jpg_102a705f-6ea3-405f-9e1a-f39d2f7dc5b5.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032135.jpg_0df06fdd-fd55-441e-9afc-56604c4c0502.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025803.jpg_88acd3a2-f914-40c9-897b-f3e8a4f45536.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032206.jpg_4f8e01b6-6d73-46d4-83cb-cac1ad41d8fc.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026765.jpg_bdacb7ae-c502-4925-84c2-06674310c300.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032437.jpg_961e0cb3-192b-4038-ae7a-d84d2227ceeb.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031381.jpg_8434d0ad-9b60-4f4d-aff5-2fdca7e4ba42.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027650.jpg_bcddd5a2-6e8f-4606-b66a-61238f32bada.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025825.jpg_316d596b-e378-417a-8404-5377c8d5bd4d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029713.jpg_d6d7c6e7-096a-4f7d-981e-85283f6af101.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026040.jpg_568ae5d7-bed3-4fab-9029-963927e5e41d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031335.jpg_e6bdd498-3bd9-4878-862e-86eec0bfabbd.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031108.jpg_7603b670-dc13-4545-bbce-d1253e9c0e01.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026729.jpg_e1cc600e-e52a-40ce-a46a-c71733fb0ad5.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029781.jpg_4fb4d264-6077-454f-a307-d0ffa3a3dc9c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031823.jpg_224db2eb-2457-41be-977c-7acbfb0d93b6.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032135.jpg_55799ae9-0e66-46af-94dc-cface10abcbc.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028190.jpg_10698b9e-5d3c-43a8-a70e-6744e5086a56.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029025.jpg_e0c077a7-1d5a-4aea-a9d2-94379643735c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029025.jpg_f6fb6f97-8876-4c5d-be0f-2c1be0851667.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027650.jpg_304cc74b-ee50-494e-81a4-004b0f58aa26.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030036.jpg_1eba4ae7-7370-456a-bed8-465519a258ab.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028314.jpg_88c9054d-b8fa-4439-8d6b-6006bf43060e.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033151.jpg_280e4fe3-ddf1-49c4-ab18-1cc09f8d6b2d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029827.jpg_543acb73-46c3-486d-92b4-d9a14394181f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029915.jpg_d13722aa-e3e6-4a27-9ac9-03a94e6e0a94.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033811.jpg_e6fd532d-b0ee-4134-a70c-b87122b5df5f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029460.jpg_75366302-9586-4c8d-a218-86dd57161869.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029713.jpg_12c339d6-8ea1-4466-9d15-a31d0282f261.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025803.jpg_7c5bbabd-c13e-455e-ba03-9ec7ed49ada9.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029915.jpg_815f1f6d-855b-4d3b-a1c6-9bec991dbb8d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032437.jpg_4f184d9f-667f-441a-966e-a1d6e6aa511d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026729.jpg_216897fc-0b99-4dc7-96f4-65328bc946b9.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026626.jpg_0db8d990-77dc-48e5-b7ac-5eb0f1cf7ca0.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027615.jpg_c68bd2a6-3eee-47db-b2b8-07b71e5a1816.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029025.jpg_3b862773-7dc9-466f-9744-6358ab35beae.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033705.jpg_97c9e891-2558-4e84-844a-e6f221b5e319.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026729.jpg_35cce2f5-ad8b-458f-8b88-4ba6586c0fc4.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029041.jpg_aa8bf719-f604-4a7d-9f38-01cd3dc86efe.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026040.jpg_2c573a36-ccf8-49de-8822-93df5e65d946.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032404.jpg_e6cfe382-733b-4e95-8542-01d2b659b6d7.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029210.jpg_181ecf32-b487-4e7e-81b1-0d8ea74c6441.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031292.jpg_c003408b-b532-470a-8935-4179b71d6c63.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025780.jpg_e8c15762-6c00-41ba-b738-5d07a8d0336d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029930.jpg_d647bacc-7362-4333-8ad3-788b0caebc44.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025825.jpg_99ba65dd-8059-412d-848e-cbdb6f2a04a5.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028063.jpg_53fd3acf-bb7c-43e9-802b-7d1b4778017f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033456.jpg_cf2fa3e0-0fc2-4299-ad97-a657db75da98.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029930.jpg_b5cfc6a4-9e93-4791-a635-85d02c9690c0.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025780.jpg_dde6394b-10be-4747-9d22-6b152398a054.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025992.jpg_2a6b6ce2-57b7-4c3d-b1ec-d8ca89431fdb.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033456.jpg_18ac0373-ce74-4e94-9f95-270c8cf75959.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028820.jpg_0d97136c-8727-42e8-bdd3-cc639d8670be.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027447.jpg_21044f97-8789-40ab-b7a6-4e7cf2064b7c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026709.jpg_7506cf19-8881-47d0-a939-f13521588b5c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030463.jpg_6c4acbf1-a6fa-4455-84fc-b61643ac03de.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026212.jpg_8bf17788-f47f-44eb-a048-72e55cadb3f4.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027802.jpg_d90eb36c-8ca7-4975-8a7f-09643a481c84.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028854.jpg_912467de-bb6c-4e14-8d2b-93c9a66acdf7.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029460.jpg_96fa0b1f-9e0b-47f5-8548-479397cdae8c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030242.jpg_9b7fb007-c709-4495-9714-e39d9a3ae1ee.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033358.jpg_0a40118c-cf33-4f77-8090-7b44d40354ee.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033705.jpg_109a79d4-b3b9-4894-ad0e-aef44e30b624.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030133.jpg_17e64c8f-0efe-4405-be15-9578e598eef4.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031506.jpg_3e4bda15-707a-4960-b8d4-01dd2bdd2a5f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027896.jpg_0f2f2f23-77a2-47cb-8cea-8302cff828c9.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026171.jpg_e14bf9bf-c1af-46c2-b3c7-f5007fc8de2b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029781.jpg_3be6c9b4-c63b-4aa7-8a4b-65dbe0076cd7.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032135.jpg_ce99939e-2968-4c02-b18c-762bc40becfd.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026905.jpg_72b4e006-8ddf-4256-b3be-a034c3a735a9.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031381.jpg_edd1e3b6-7669-4e58-90ee-f70607cda007.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025780.jpg_e76367b1-960a-427c-85c3-65e1e70e9fa3.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032422.jpg_80b22020-d0a8-44af-8e0e-b0251c89e65d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027884.jpg_f623be4d-a82f-47eb-a562-33130a9ece9c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025953.jpg_b7e969d3-ff67-4058-8cf6-f067e6073209.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031993.jpg_0c3b6187-a152-4967-b170-80ec333a2f84.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026575.jpg_2f5a8c37-0ebe-4695-994a-a2c6a3d95783.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028990.jpg_e4a9c65b-8c74-4f9b-9352-fa5f9a21a7e3.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030463.jpg_0c1329a7-8841-4b7d-839f-8fcbd711251b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026984.jpg_da68fb90-b8c5-4fc1-9f73-9c2880143ec7.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027447.jpg_a4f18503-474a-4eda-82ec-e310284ce276.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026984.jpg_f239a58c-b491-4671-a9a0-d69376f85e5b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025992.jpg_f24ec331-dafb-4027-82e8-c82e504ca58b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026765.jpg_dd213231-de38-460f-9fa9-4e75542a361e.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027580.jpg_f6e9b501-dd9e-4e73-8188-45a0b4282cd0.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029133.jpg_70a89304-e7da-4ebc-926a-fe0d58ef6903.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029827.jpg_046f6947-d4ed-41c4-9cfe-d19d92d9bb2f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030142.jpg_638cd810-5b84-4a20-994f-c36c3bc1ac88.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027829.jpg_b2fd204e-45a0-4daa-8a46-d798ab82cfdc.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029500.jpg_4d14c28b-7b73-4b82-9ee7-5a8a4726b049.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030825.jpg_12e6be6f-096e-4437-a6e8-c9a8617ca555.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030142.jpg_b247c232-ae81-4763-8209-439864a27655.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030036.jpg_e87488e9-54b4-4971-a182-82d272f2a7f4.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029827.jpg_665bf846-07b0-409f-94fd-6f69c9e5f56b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032135.jpg_fb817a15-df2c-4598-a0d8-a1aeb2196777.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029840.jpg_dd76e153-35ce-4b0a-a471-47ca1f0c5cbf.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025803.jpg_a7ef4827-aeaf-4b82-9c58-097a4ed49fc8.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030586.jpg_bdee09b4-97a0-4212-8047-1bc5dad21ab5.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030586.jpg_f1d1e3d7-b8fa-41ef-9ac7-8dcd7b0eacaf.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032404.jpg_4183a0fc-a433-40f5-b1fa-7d27ce9a2464.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030826.jpg_954aba31-212c-471d-9f02-1ac5cc4a3b89.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025803.jpg_d7fac668-f11c-41a8-aedd-657ebbc04e33.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026575.jpg_4cdffaba-dd4d-4eb6-a137-e6fe532d0f75.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029460.jpg_eefa2d2a-72b2-4648-9e34-a65a4b064a28.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030826.jpg_e9716a0c-b723-4fb3-a325-3aa747be8590.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033494.jpg_7b914285-0b80-4935-84b4-62feae440c2d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032437.jpg_bb958793-ff49-4508-a8e2-bd3ba8b896b7.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029781.jpg_e78269cd-23d8-466e-9869-6dfbcf2cfc97.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030586.jpg_90d1bafa-f166-4a48-ac43-ef4ef5fd8254.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030730.jpg_80292756-a1ea-4a87-b7fa-7c507dab204c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030133.jpg_0881411c-a57c-4a33-a654-f7ac09033f98.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028314.jpg_424f2b54-dce4-4b67-b3df-bb1daaa982c9.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029830.jpg_7436eef4-9e66-42f5-89f8-576c10a92084.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026626.jpg_e06d0aad-0206-4043-96f1-51dbe0144a30.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026709.jpg_8ab8eae4-0ba5-483d-afa3-e6f436f90a6c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033811.jpg_f6e468a1-6e2e-471b-870a-dbdd98205fd3.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029133.jpg_e446d6bc-76f2-4f22-be40-92a1f58cb32c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029025.jpg_2e1d3698-dbad-4507-9777-ff90b9aedb60.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028076.jpg_78ddca4b-77e3-4600-8d4a-6d2886e5b589.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028063.jpg_91ba1b90-9b53-44f4-9d75-526be74a450f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027615.jpg_b8739476-81fe-40e7-a6e0-57545a988820.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033151.jpg_04ab2ef3-c4e9-46a2-a44c-09d183ee5059.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032199.jpg_c65660c3-2ef2-4439-9118-7860f047d65c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027172.jpg_ab370137-2f1b-414f-bd9b-f6f513b452ab.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030586.jpg_f481bb46-144e-4354-b285-56a6e0f00bd6.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031823.jpg_65368bbc-c437-49a6-a6d7-fbc2ec9d64f8.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029133.jpg_2c6c706b-8208-4f86-adc7-1abd45bbcbd2.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028558.jpg_6f0fa190-f8f0-49ec-ac7e-d0531e0b326d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030036.jpg_9dfa5499-4bfd-4399-b424-eea301f5264a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025825.jpg_52c5edc1-19f1-4bef-be6e-f9a0545073ec.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029830.jpg_ce796c05-9bb2-4d60-a095-45b56806e450.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028076.jpg_fe7ce2f3-d11d-49ac-b2a6-a1e1f6e51b49.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033456.jpg_3a3c8f2b-18fd-4e33-b3a2-ebf959df6a9a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031823.jpg_1e6ce782-1914-4ac6-80ed-391e25f615fa.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026171.jpg_b32e2ee3-2442-4baf-93cb-c92532d40def.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026468.jpg_0d8da614-6b3e-4b71-8424-e8fc93916cef.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026457.jpg_ff82fc4e-2c2c-4e68-82b2-c2a59b0eee18.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025825.jpg_c88c37f1-e216-40f7-845b-15370c73fbb2.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028190.jpg_5a64287b-c209-445c-b518-2b01ae13c7f6.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032135.jpg_4b59c617-fe2b-4e1e-bb4f-028f9a7f3c0d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030133.jpg_817963f6-14e2-4051-b092-886e3231c6cf.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026212.jpg_008a5e49-c546-4047-9409-e8b4800ab142.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026575.jpg_72e105f6-655a-49a9-a647-d45451f88db0.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030825.jpg_bc653dc7-dd6d-4921-bded-9d224fc95a49.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033151.jpg_930cb4e9-bc7f-405a-b859-e20c24f1d487.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031108.jpg_8dba3d95-8ea4-43dc-89b6-5b27d3b288dc.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027829.jpg_ea052cf6-b2ef-44d5-a2d5-d3a188e04b97.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027896.jpg_b408d08f-5a5b-4fbf-936d-5fe0651aacc8.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030730.jpg_60e8db26-3587-4cd9-82f8-5cd21ce286a9.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029830.jpg_cce94fee-1552-49a4-a0b7-b37dcff7dd71.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029930.jpg_a0aa2da0-8904-40b3-8ae5-47b2b0723b1b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028190.jpg_fbf9b0ba-2dda-49c3-b6a6-2ec18c6715f4.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033456.jpg_193f7b19-7df5-4753-8439-c923d3b00750.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027802.jpg_7ba285be-d849-4ae1-a11c-de400b194f1c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030586.jpg_13394e28-491c-46e5-ab70-985b7cac13db.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026709.jpg_1207a5e0-c4fc-4ce6-9393-863f876d9948.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031108.jpg_6a0e2d42-f42c-43c5-b4c9-3efb86238bf6.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025992.jpg_d56cba32-468f-4eb9-b898-89a9994d96a8.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026212.jpg_21f29902-759c-4221-8d22-ce21d56b0898.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028990.jpg_901ac7ec-1442-480a-bcde-d60cbc5b7baf.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027896.jpg_3b84f602-4001-4a76-9096-91bbfe18ba8a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027452.jpg_2148f7e0-59b4-45aa-99aa-a8322da2a7ab.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025992.jpg_4ce21a9c-17cd-4673-a0fd-cffbee22bb50.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029830.jpg_f75eceb7-2673-4c6b-bc0e-9e8525e88fb1.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029830.jpg_b8a97b9a-d465-4d33-9265-b845a89fb886.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033494.jpg_da2d0241-ded1-48df-ae97-ae7f044881a6.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031609.jpg_2d3eb369-efa7-4983-8159-512d819ff78d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031993.jpg_dda371dd-1675-49ab-b769-c81452d8a2ee.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026457.jpg_11436bb7-a26e-4110-9805-0b6fdc200730.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026650.jpg_88fec063-408e-43f2-88a2-560710609541.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026848.jpg_4b43f4a7-d98f-452a-b05b-b985fb8fdc30.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028941.jpg_70390c5c-76e5-4823-8adb-1b289ebb0f11.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031922.jpg_87e58971-0103-4e2f-af99-aa14cfbdf2d0.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026040.jpg_eeed926a-56f2-4cb6-b09c-794dacee4e72.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030344.jpg_5be4fd52-a0bf-4cb6-96c5-7100f3ae6798.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027536.jpg_57ccade4-bf39-4727-a74c-74a5de129114.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032854.jpg_031e3603-4d57-44d4-acc2-2e161ed27267.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027950.jpg_c6866f0e-118d-4b8f-8297-109b6ba43d08.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026625.jpg_2382b76d-0b4c-4c20-84c1-15f44386f67a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026194.jpg_ad63d36c-1745-41bb-924b-7fb5eaac1718.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028314.jpg_80d83ca2-c18d-4e11-a440-8983e4736c69.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028314.jpg_f359ff9d-c8e4-4c62-b06b-67c57b55c5d4.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026765.jpg_4326723a-a466-4744-a23f-5d9e15b0f7a7.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031823.jpg_4ae262b4-d955-40c5-ba0a-de11ebce00ad.jpg',
# ...
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000220.jpg_fbb74220-50d3-4b0b-8f05-c55dbdb04bf5.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000460.jpg_4e256af5-df00-4c61-86a2-50864262932c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0027334.jpg_e540a875-405b-471f-aa97-cea1249a45dd.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000260.jpg_19bc4bed-60cc-4fc4-be44-6b8c6d6baaca.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0025427.jpg_0b978960-b3f2-47e3-8b8b-01947318d04c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000499.jpg_161f0e31-c17d-4ece-9702-fd881c240303.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0028190.jpg_ba349f06-5597-4623-906b-290e7f56c6d9.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0027536.jpg_3b35a221-a2e4-4877-8403-f82acf40ea28.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000037.jpg_156373f1-c662-4a22-b8ce-e1e4fd46d5c5.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000084.jpg_0f5ffe62-785e-4743-89ac-545ba401d136.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0027884.jpg_81a7f31b-b151-45dd-b63b-7341e305ef0c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000057.jpg_4b8862aa-c706-4e49-a7f4-6299a8e859c0.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000326.jpg_667f7ba9-7157-47ba-9e5d-b390ffffdb5a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000431.jpg_93157103-28e0-4d2f-aa2e-420a463e6646.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000540.jpg_bae13c60-3e64-4096-b74f-cc4140c60ee3.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000321.jpg_726d9206-fa20-4078-ad24-c9c26d77531f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000372.jpg_1a3e98b5-eebb-425a-946e-52b840ee4fec.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0026212.jpg_7c5227a3-c17f-476d-9de3-4d8bf70a84c3.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0027536.jpg_b0f92fc6-2973-41be-9046-bec610e11735.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000317.jpg_eb4346b6-b244-4461-8718-1b1102bab90b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000093.jpg_7ad8de3a-5b58-494b-9e0b-1e6fa2b88bc5.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000373.jpg_7a526b2a-2192-488a-ad42-8170793c03d4.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0027447.jpg_36841d20-240f-4ba0-8e1c-cc1aee225a3a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000379.jpg_8933f11c-9480-4d69-8079-bbee19af79d3.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0026625.jpg_292dc42e-bfa5-4687-b26b-f82b9e822969.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000478.jpg_8fc053ef-c11b-423e-b974-b83509924f2d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000384.jpg_d027276d-f2d7-4356-9e99-275cd8f0f609.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000047.jpg_098a365d-53cc-43cd-91aa-6ac511223f1e.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000053.jpg_09a4f876-7c29-4eae-aadf-cc38bfbd12d8.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000258.jpg_81662647-f1de-46bd-aba3-810ce92043fe.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0026457.jpg_981b3604-ac89-4074-ae11-3e0e4f85cf56.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000375.jpg_a38fa1c4-d64d-4681-b09d-60e30e4c7578.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000334.jpg_25b0f945-e6b7-43ca-b83e-9eb714e05b3b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000392.jpg_ecce5556-9a8d-4e4a-be70-77e8abd4b3dd.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000231.jpg_139d3dbb-c5c2-45a1-a533-bc0f16f3dd50.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000334.jpg_e7b24e7c-1938-409d-a288-092dea406e80.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0025953.jpg_d6c5eaec-8237-43f3-afeb-2ffca897f8a5.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0028190.jpg_382a1787-2d84-4ccf-a984-7f17726b59a1.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000093.jpg_dd85d458-58b8-47fb-be6e-c68d9221564f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000063.jpg_67e1836e-2313-4573-aea3-a8ad410f86c2.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000256.jpg_e232ac02-b506-4017-85be-a128b5dd8d40.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0024646.jpg_52c8203e-9462-4d8e-ba63-a3197d4533ca.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000250.jpg_972ba27e-798f-4430-9dfe-f08822d8176c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0029141.jpg_a90ed359-1d02-4a50-9fdd-dce5c9cb860b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000545.jpg_53cca44d-6340-4734-b34d-878a508ccff3.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000389.jpg_4454bf94-19af-4879-9fb9-099cb92441d4.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000384.jpg_785765dc-d410-44a0-9c75-0a57577ba5df.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0027615.jpg_7d5a61cd-225f-4229-9168-2a86c748d9a6.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000476.jpg_97ecf283-c4bc-4c10-9790-177a70b27f14.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000473.jpg_52209106-284d-4378-acad-0e6fff02d37d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000365.jpg_d9631b66-6ca4-4e6b-8d04-768ebc711183.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000501.jpg_8f27c797-0015-4593-9eb1-450e2287d574.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0028558.jpg_d4acae8f-a654-4790-b9e7-0995ae85a2a3.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000338.jpg_e3992bde-453b-43b3-a147-62bb927e1d83.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000320.jpg_e40de90f-2251-4710-a6a3-ae156cd357b9.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000373.jpg_dc2f5b7e-a474-4040-9e0d-b643601f9722.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0024763.jpg_03e741f5-9831-4410-be6d-326b55f89988.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000352.jpg_9915e1a3-6018-4b76-a3ea-4041787637eb.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000448.jpg_37c8cc9a-07c5-4d88-b879-e46f49a6a652.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0026984.jpg_02ba71b9-9c57-493e-843e-a714df126707.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0026765.jpg_806f453b-62bc-4f86-893d-9447cdc9342f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000080.jpg_8178142c-6284-458d-ac48-16cd256dc6be.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000222.jpg_921d1204-f563-466b-9b4e-f90a1cf546e2.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000227.jpg_fa2dd1c0-1c34-42c2-905a-c66ae392f25a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000425.jpg_1a66b6e5-e081-4868-8255-ed4de9c356a1.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000317.jpg_16aa6d20-fc3b-4fde-a462-afa97b71b55b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0028370.jpg_27f7e724-3da7-4a5d-be5e-4c9c334161e4.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0029210.jpg_6f66fe50-920c-4c4a-b1b7-de4a75c4602e.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0025605.jpg_3e0c39d6-3e3a-411f-9008-306cfbf8a1e6.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0028314.jpg_63105d97-4c2e-43ca-b8e8-469aab903cb6.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000370.jpg_e5715955-0a57-43cf-938b-a55a9e58b949.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000489.jpg_15bf8e62-6dc2-4d25-86f0-8f5cb42f83b2.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000426.jpg_7955aed8-f50e-49aa-8513-08f43cf14a08.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000375.jpg_4861d42c-8755-4e52-9736-2f5258e60dc4.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000449.jpg_59543e14-d5ed-47aa-9920-28269df41375.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  ...]

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
path_list = [x for x in glob(os.path.join(data_dir_train,'*','*.jpg'))]

# %%
lesion_list = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train,'*','*.jpg'))]

# %%
dataframe_dict = dict(zip(path_list, lesion_list))

# %%
original_df = pd.DataFrame(list(dataframe_dict.items()),columns=['Path','Label'])

# %%
original_df['Label'].value_counts()
# Out:
# Train    2239
# Name: Label, dtype: int64

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)
# Out:
# <ipython-input-43-17a6b079869a>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = original_df.append(df2)

# %%
new_df['Label'].value_counts()
# Out:
# Train                         2239
# actinic keratosis              500
# nevus                          500
# seborrheic keratosis           500
# dermatofibroma                 500
# pigmented benign keratosis     500
# vascular lesion                500
# squamous cell carcinoma        500
# basal cell carcinoma           500
# melanoma                       500
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train="/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "training",## Todo choose the correct parameter value, so that only training data is refered to,,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "validation",## Todo choose the correct parameter value, so that only validation data is refered to,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here
num_classes = 9
model = tf.keras.Sequential([
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 50
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# 169/169 [==============================] - 46s 250ms/step - loss: 2.1131 - accuracy: 0.3153 - val_loss: 1.4600 - val_accuracy: 0.4477
# Epoch 2/50
# 169/169 [==============================] - 20s 117ms/step - loss: 1.3702 - accuracy: 0.4918 - val_loss: 1.2912 - val_accuracy: 0.5316
# Epoch 3/50
# 169/169 [==============================] - 20s 112ms/step - loss: 1.0943 - accuracy: 0.6052 - val_loss: 1.1504 - val_accuracy: 0.5969
# Epoch 4/50
# 169/169 [==============================] - 20s 115ms/step - loss: 0.8840 - accuracy: 0.6871 - val_loss: 1.0553 - val_accuracy: 0.6377
# Epoch 5/50
# 169/169 [==============================] - 20s 113ms/step - loss: 0.7264 - accuracy: 0.7509 - val_loss: 0.9849 - val_accuracy: 0.6733
# Epoch 6/50
# 169/169 [==============================] - 20s 114ms/step - loss: 0.5413 - accuracy: 0.8144 - val_loss: 0.8975 - val_accuracy: 0.7112
# Epoch 7/50
# 169/169 [==============================] - 20s 114ms/step - loss: 0.4724 - accuracy: 0.8412 - val_loss: 0.8849 - val_accuracy: 0.7313
# Epoch 8/50
# 169/169 [==============================] - 20s 113ms/step - loss: 0.4001 - accuracy: 0.8728 - val_loss: 0.9616 - val_accuracy: 0.6904
# Epoch 9/50
# 169/169 [==============================] - 20s 115ms/step - loss: 0.3154 - accuracy: 0.8993 - val_loss: 0.8280 - val_accuracy: 0.7379
# Epoch 10/50
# 169/169 [==============================] - 20s 112ms/step - loss: 0.2691 - accuracy: 0.9108 - val_loss: 0.9119 - val_accuracy: 0.7565
# Epoch 11/50
# 169/169 [==============================] - 21s 120ms/step - loss: 0.2232 - accuracy: 0.9264 - val_loss: 0.8960 - val_accuracy: 0.7587
# Epoch 12/50
# 169/169 [==============================] - 20s 113ms/step - loss: 0.2009 - accuracy: 0.9327 - val_loss: 0.8591 - val_accuracy: 0.7736
# Epoch 13/50
# 169/169 [==============================] - 20s 115ms/step - loss: 0.2202 - accuracy: 0.9254 - val_loss: 0.8631 - val_accuracy: 0.7676
# Epoch 14/50
# 169/169 [==============================] - 20s 112ms/step - loss: 0.1743 - accuracy: 0.9416 - val_loss: 0.8139 - val_accuracy: 0.7899
# Epoch 15/50
# 169/169 [==============================] - 20s 115ms/step - loss: 0.1632 - accuracy: 0.9403 - val_loss: 1.0837 - val_accuracy: 0.7201
# Epoch 16/50
# 169/169 [==============================] - 19s 111ms/step - loss: 0.1668 - accuracy: 0.9423 - val_loss: 0.8946 - val_accuracy: 0.7699
# Epoch 17/50
# 169/169 [==============================] - 20s 115ms/step - loss: 0.1476 - accuracy: 0.9492 - val_loss: 0.8707 - val_accuracy: 0.7906
# Epoch 18/50
# 169/169 [==============================] - 19s 111ms/step - loss: 0.1185 - accuracy: 0.9544 - val_loss: 0.9087 - val_accuracy: 0.7892
# Epoch 19/50
# 169/169 [==============================] - 20s 115ms/step - loss: 0.1219 - accuracy: 0.9523 - val_loss: 0.9197 - val_accuracy: 0.7832
# Epoch 20/50
# 169/169 [==============================] - 19s 110ms/step - loss: 0.1481 - accuracy: 0.9466 - val_loss: 1.0203 - val_accuracy: 0.7565
# Epoch 21/50
# 169/169 [==============================] - 20s 115ms/step - loss: 0.1660 - accuracy: 0.9421 - val_loss: 1.0036 - val_accuracy: 0.7528
# Epoch 22/50
# 169/169 [==============================] - 20s 112ms/step - loss: 0.1750 - accuracy: 0.9408 - val_loss: 0.9992 - val_accuracy: 0.7840
# Epoch 23/50
# 169/169 [==============================] - 20s 114ms/step - loss: 0.1312 - accuracy: 0.9520 - val_loss: 0.9418 - val_accuracy: 0.7884
# Epoch 24/50
# 169/169 [==============================] - 20s 115ms/step - loss: 0.1238 - accuracy: 0.9520 - val_loss: 1.0376 - val_accuracy: 0.7817
# Epoch 25/50
# 169/169 [==============================] - 20s 114ms/step - loss: 0.1045 - accuracy: 0.9607 - val_loss: 0.9721 - val_accuracy: 0.7936
# Epoch 26/50
# 169/169 [==============================] - 19s 111ms/step - loss: 0.0945 - accuracy: 0.9635 - val_loss: 0.9529 - val_accuracy: 0.7921
# Epoch 27/50
# 169/169 [==============================] - 20s 117ms/step - loss: 0.0887 - accuracy: 0.9629 - val_loss: 1.1907 - val_accuracy: 0.7706
# Epoch 28/50
# 169/169 [==============================] - 21s 120ms/step - loss: 0.1113 - accuracy: 0.9568 - val_loss: 1.1178 - val_accuracy: 0.7795
# Epoch 29/50
# 169/169 [==============================] - 20s 115ms/step - loss: 0.0974 - accuracy: 0.9618 - val_loss: 1.2871 - val_accuracy: 0.7765
# Epoch 30/50
# 169/169 [==============================] - 20s 112ms/step - loss: 0.1080 - accuracy: 0.9592 - val_loss: 1.1318 - val_accuracy: 0.7817
# Epoch 31/50
# 169/169 [==============================] - 20s 115ms/step - loss: 0.0932 - accuracy: 0.9661 - val_loss: 1.2039 - val_accuracy: 0.7765
# Epoch 32/50
# 169/169 [==============================] - 20s 111ms/step - loss: 0.1494 - accuracy: 0.9505 - val_loss: 1.1480 - val_accuracy: 0.7558
# Epoch 33/50
# 169/169 [==============================] - 20s 112ms/step - loss: 0.1152 - accuracy: 0.9575 - val_loss: 1.1030 - val_accuracy: 0.7810
# Epoch 34/50
# 169/169 [==============================] - 20s 112ms/step - loss: 0.0820 - accuracy: 0.9674 - val_loss: 1.1520 - val_accuracy: 0.7743
# Epoch 35/50
# 169/169 [==============================] - 20s 114ms/step - loss: 0.0783 - accuracy: 0.9681 - val_loss: 1.2707 - val_accuracy: 0.7610
# Epoch 36/50
# 169/169 [==============================] - 20s 116ms/step - loss: 0.0925 - accuracy: 0.9607 - val_loss: 1.0970 - val_accuracy: 0.7869
# Epoch 37/50
# 169/169 [==============================] - 21s 120ms/step - loss: 0.0866 - accuracy: 0.9636 - val_loss: 1.1547 - val_accuracy: 0.7773
# Epoch 38/50
# 169/169 [==============================] - 19s 111ms/step - loss: 0.0741 - accuracy: 0.9692 - val_loss: 1.2379 - val_accuracy: 0.7728
# Epoch 39/50
# 169/169 [==============================] - 20s 115ms/step - loss: 0.1426 - accuracy: 0.9505 - val_loss: 1.2380 - val_accuracy: 0.7728
# Epoch 40/50
# 169/169 [==============================] - 19s 112ms/step - loss: 0.1197 - accuracy: 0.9609 - val_loss: 1.1573 - val_accuracy: 0.7892
# Epoch 41/50
# 169/169 [==============================] - 20s 114ms/step - loss: 0.1177 - accuracy: 0.9592 - val_loss: 1.3619 - val_accuracy: 0.7602
# Epoch 42/50
# 169/169 [==============================] - 19s 111ms/step - loss: 0.1035 - accuracy: 0.9616 - val_loss: 1.3388 - val_accuracy: 0.7699
# Epoch 43/50
# 169/169 [==============================] - 20s 115ms/step - loss: 0.0886 - accuracy: 0.9661 - val_loss: 1.4875 - val_accuracy: 0.7572
# Epoch 44/50
# 169/169 [==============================] - 20s 111ms/step - loss: 0.0854 - accuracy: 0.9675 - val_loss: 1.4210 - val_accuracy: 0.7773
# Epoch 45/50
# 169/169 [==============================] - 20s 114ms/step - loss: 0.0723 - accuracy: 0.9700 - val_loss: 1.3774 - val_accuracy: 0.7587
# Epoch 46/50
# 169/169 [==============================] - 19s 111ms/step - loss: 0.0661 - accuracy: 0.9713 - val_loss: 1.4485 - val_accuracy: 0.7624
# Epoch 47/50
# 169/169 [==============================] - 20s 115ms/step - loss: 0.0687 - accuracy: 0.9716 - val_loss: 1.5471 - val_accuracy: 0.7587
# Epoch 48/50
# 169/169 [==============================] - 19s 111ms/step - loss: 0.0634 - accuracy: 0.9726 - val_loss: 1.6595 - val_accuracy: 0.7513
# Epoch 49/50
# 169/169 [==============================] - 21s 117ms/step - loss: 0.1305 - accuracy: 0.9546 - val_loss: 1.6816 - val_accuracy: 0.7424
# Epoch 50/50
# 169/169 [==============================] - 20s 112ms/step - loss: 0.1057 - accuracy: 0.9581 - val_loss: 1.5630 - val_accuracy: 0.7572

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?
