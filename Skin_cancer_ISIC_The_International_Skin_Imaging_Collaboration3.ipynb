# %% [markdown]
# <a href="https://colab.research.google.com/github/Sheetal-R/Melanoma_detection_assignment/blob/main/Skin_cancer_ISIC_The_International_Skin_Imaging_Collaboration3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problem statement:** To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution that can evaluate images and alert dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.</br>
#
# **Project Pipeline**
# - Data Reading/Data Understanding → Defining the path for train and test images
# - Dataset Creation→ Create train & validation dataset from the train directory with a batch size of 32. Also, make sure you resize your images to 180*180.
# - Dataset visualisation → Create a code to visualize one instance of all the nine classes present in the dataset
# - Model Building & training :
#   - Create a CNN model, which can accurately detect 9 classes present in the dataset. While building the model, rescale images to normalize pixel values between (0,1).
#   - Choose an appropriate optimiser and loss function for model training
#   - Train the model for ~20 epochs
#   - Write your findings after the model fit. You must check if there is any evidence of model overfit or underfit.
# - Chose an appropriate data augmentation strategy to resolve underfitting/overfitting
# - Model Building & training on the augmented data :
#   - Create a CNN model, which can accurately detect 9 classes present in the dataset. While building the model rescale images to normalize pixel values between (0,1).
#   - Choose an appropriate optimiser and loss function for model training
#   - Train the model for ~20 epochs
#   - Write your findings after the model fit, see if the earlier issue is resolved or not?
# - Class distribution: Examine the current class distribution in the training dataset
#   - Which class has the least number of samples?
#   - Which classes dominate the data in terms of the proportionate number of samples?
# - Handling class imbalances: Rectify class imbalances present in the training dataset with Augmentor library.
# - Model Building & training on the rectified class imbalance data :
#   - Create a CNN model, which can accurately detect 9 classes present in the dataset. While building the model, rescale images to normalize pixel values between (0,1).
#   - Choose an appropriate optimiser and loss function for model training
#   - Train the model for ~30 epochs
#   - Write your findings after the model fit, see if the issues are resolved or not?

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Jul 11 23:51:43 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    24W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# #### Importing Libraries

# %%
# !pip install -q keras

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from google.colab import drive
from glob import  glob

# %% [markdown]
# ### Mount Google Drive and use path to import the train and test data

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Defining the path for train and test images
## Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %% [markdown]
# Create DF to View Data

# %%
# Create dataframes
train_df = pd.DataFrame(columns=['image_path', 'label'])
test_df = pd.DataFrame(columns=['image_path', 'label'])

# %%
# Add images paths and labels to dataframes

def appendDictToDF(df,dictToAppend):
  df = pd.concat([df, pd.DataFrame.from_records([dictToAppend])])
  return df


for label, directory in enumerate(os.listdir(data_dir_train)):
    for filename in os.listdir(os.path.join(data_dir_train, directory)):
        image_path = os.path.join(data_dir_train, directory, filename)
        #train_df = train_df.append({'image_path': image_path, 'label': label}, ignore_index=True)
        train_df = appendDictToDF(train_df,{'image_path': image_path, 'label': label})


for label, directory in enumerate(os.listdir(data_dir_test)):
    for filename in os.listdir(os.path.join(data_dir_test, directory)):
        image_path = os.path.join(data_dir_test, directory, filename)
        test_df = appendDictToDF(test_df,{'image_path': image_path, 'label': label})

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (2239, 2)
# (118, 2)

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %%
# Get list of directories in train_dir
labels = os.listdir(data_dir_train)

# Create label_map dictionary
label_map = {i: label for i, label in enumerate(labels)}
num_classes=len(label_map)
label_map
# Out:
# {0: 'actinic keratosis',
#  1: 'nevus',
#  2: 'seborrheic keratosis',
#  3: 'dermatofibroma',
#  4: 'pigmented benign keratosis',
#  5: 'vascular lesion',
#  6: 'squamous cell carcinoma',
#  7: 'basal cell carcinoma',
#  8: 'melanoma'}

# %%
# Count the number of images in each class
class_counts = train_df['label'].value_counts().sort_index()

# Print the number of images in each class
print("Dataset Summary")
print("-" * 60)
print(f"{'Class Label':<15} {'Class Name':<30} {'Count':<10}")
print("-" * 60)
for class_label, class_name in label_map.items():
    count = class_counts[class_label]
    print(f"{class_label:<15} {class_name:<30} {count:<10}")
print("-" * 60)
print(f"{'Total':<45} {sum(class_counts):<10}")
# Out:
# Dataset Summary
# ------------------------------------------------------------
# Class Label     Class Name                     Count
# ------------------------------------------------------------
# 0               actinic keratosis              114
# 1               nevus                          357
# 2               seborrheic keratosis           77
# 3               dermatofibroma                 95
# 4               pigmented benign keratosis     462
# 5               vascular lesion                139
# 6               squamous cell carcinoma        181
# 7               basal cell carcinoma           376
# 8               melanoma                       438
# ------------------------------------------------------------
# Total                                         2239

# %% [markdown]
# Found 2239 files belonging to 9 classes.

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_test,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 118 files belonging to 9 classes.
# Using 23 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(3):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model - normalize pixel values between (0,1)

# %%
### Your code goes here
num_classes = 9 # as target class has 9 labels
model = tf.keras.Sequential([
  layers.experimental.preprocessing.Rescaling(1.0/255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, (3, 3), padding="same", activation='relu'),
  layers.Conv2D(16, (3, 3), activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Conv2D(32, (3, 3), padding="same", activation='relu'),
  layers.Conv2D(32, (3, 3), activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Conv2D(64, (3, 3), padding="same", activation='relu'),
  layers.Conv2D(64, (3, 3), activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Conv2D(128, (3, 3), activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Flatten(),
  layers.Dense(256, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
###  Optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.build(input_shape=(None,180,180,3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  conv2d_1 (Conv2D)           (None, 178, 178, 16)      2320
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 16)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 89, 89, 32)        4640
#
#  conv2d_3 (Conv2D)           (None, 87, 87, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 43, 43, 64)        18496
#
#  conv2d_5 (Conv2D)           (None, 41, 41, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 18, 18, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dense (Dense)               (None, 256)               2654464
#
#  dense_1 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 2,802,713
# Trainable params: 2,802,713
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 140s 71ms/step - loss: 2.0512 - accuracy: 0.1842 - val_loss: 2.4178 - val_accuracy: 0.1739
# Epoch 2/20
# 56/56 [==============================] - 1s 17ms/step - loss: 2.0094 - accuracy: 0.2227 - val_loss: 2.4940 - val_accuracy: 0.3043
# Epoch 3/20
# 56/56 [==============================] - 1s 17ms/step - loss: 1.8708 - accuracy: 0.2958 - val_loss: 2.1118 - val_accuracy: 0.2609
# Epoch 4/20
# 56/56 [==============================] - 1s 17ms/step - loss: 1.7387 - accuracy: 0.3532 - val_loss: 2.1134 - val_accuracy: 0.1739
# Epoch 5/20
# 56/56 [==============================] - 1s 17ms/step - loss: 1.6063 - accuracy: 0.4219 - val_loss: 2.9937 - val_accuracy: 0.3043
# Epoch 6/20
# 56/56 [==============================] - 1s 16ms/step - loss: 1.5611 - accuracy: 0.4369 - val_loss: 2.2211 - val_accuracy: 0.2609
# Epoch 7/20
# 56/56 [==============================] - 1s 17ms/step - loss: 1.4814 - accuracy: 0.4749 - val_loss: 2.3666 - val_accuracy: 0.2174
# Epoch 8/20
# 56/56 [==============================] - 1s 17ms/step - loss: 1.4597 - accuracy: 0.4900 - val_loss: 2.3418 - val_accuracy: 0.3043
# Epoch 9/20
# 56/56 [==============================] - 1s 18ms/step - loss: 1.4382 - accuracy: 0.4844 - val_loss: 2.5082 - val_accuracy: 0.1739
# Epoch 10/20
# 56/56 [==============================] - 1s 17ms/step - loss: 1.3663 - accuracy: 0.5167 - val_loss: 3.0812 - val_accuracy: 0.3043
# Epoch 11/20
# 56/56 [==============================] - 1s 17ms/step - loss: 1.3534 - accuracy: 0.5162 - val_loss: 2.5795 - val_accuracy: 0.1739
# Epoch 12/20
# 56/56 [==============================] - 1s 17ms/step - loss: 1.2522 - accuracy: 0.5608 - val_loss: 2.4540 - val_accuracy: 0.2609
# Epoch 13/20
# 56/56 [==============================] - 1s 17ms/step - loss: 1.2626 - accuracy: 0.5419 - val_loss: 2.3932 - val_accuracy: 0.1739
# Epoch 14/20
# 56/56 [==============================] - 1s 16ms/step - loss: 1.2420 - accuracy: 0.5541 - val_loss: 3.0338 - val_accuracy: 0.2174
# Epoch 15/20
# 56/56 [==============================] - 1s 16ms/step - loss: 1.1426 - accuracy: 0.5804 - val_loss: 2.8178 - val_accuracy: 0.2609
# Epoch 16/20
# 56/56 [==============================] - 1s 17ms/step - loss: 1.0832 - accuracy: 0.6077 - val_loss: 3.0609 - val_accuracy: 0.2609
# Epoch 17/20
# 56/56 [==============================] - 1s 17ms/step - loss: 1.0232 - accuracy: 0.6311 - val_loss: 3.2331 - val_accuracy: 0.3043
# Epoch 18/20
# 56/56 [==============================] - 1s 16ms/step - loss: 0.9288 - accuracy: 0.6641 - val_loss: 3.1163 - val_accuracy: 0.2174
# Epoch 19/20
# 56/56 [==============================] - 1s 17ms/step - loss: 0.8542 - accuracy: 0.6853 - val_loss: 2.9438 - val_accuracy: 0.3478
# Epoch 20/20
# 56/56 [==============================] - 1s 17ms/step - loss: 0.8158 - accuracy: 0.7015 - val_loss: 3.9015 - val_accuracy: 0.3043

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here

# %%
# Choosing an appropriate data augumentation strategy.
# Your code goes here
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical",input_shape=(img_height, img_width, 3)),
  layers.experimental.preprocessing.RandomCrop(height=img_height, width=img_width, seed=123),
  layers.experimental.preprocessing.RandomRotation(0.2),
  layers.experimental.preprocessing.RandomZoom(height_factor=0.3, width_factor=0.3,),
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(5):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
model = tf.keras.Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1.0/255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, (3, 3), padding="same", activation='relu'),
  layers.Conv2D(16, (3, 3), activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Conv2D(32, (3, 3), padding="same", activation='relu'),
  layers.Conv2D(32, (3, 3), activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Dropout(0.2),
  layers.Conv2D(64, (3, 3), padding="same", activation='relu'),
  layers.Conv2D(64, (3, 3), activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Conv2D(128, (3, 3), activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(256, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.build(input_shape=(None,180,180,3))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_7 (Conv2D)           (None, 180, 180, 16)      448
#
#  conv2d_8 (Conv2D)           (None, 178, 178, 16)      2320
#
#  max_pooling2d_4 (MaxPooling  (None, 89, 89, 16)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 89, 89, 32)        4640
#
#  conv2d_10 (Conv2D)          (None, 87, 87, 32)        9248
#
#  max_pooling2d_5 (MaxPooling  (None, 43, 43, 32)       0
#  2D)
#
#  dropout (Dropout)           (None, 43, 43, 32)        0
#
#  conv2d_11 (Conv2D)          (None, 43, 43, 64)        18496
#
#  conv2d_12 (Conv2D)          (None, 41, 41, 64)        36928
#
#  max_pooling2d_6 (MaxPooling  (None, 20, 20, 64)       0
#  2D)
#
#  conv2d_13 (Conv2D)          (None, 18, 18, 128)       73856
#
#  max_pooling2d_7 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 9, 9, 128)         0
#
#  flatten_1 (Flatten)         (None, 10368)             0
#
#  dense_2 (Dense)             (None, 256)               2654464
#
#  dense_3 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 2,802,713
# Trainable params: 2,802,713
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
history = model.fit(
  train_ds,
  batch_size=batch_size,
  validation_data=val_ds, epochs=epochs)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 5s 29ms/step - loss: 2.0008 - accuracy: 0.2338 - val_loss: 2.4346 - val_accuracy: 0.2609
# Epoch 2/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.7849 - accuracy: 0.3454 - val_loss: 2.6486 - val_accuracy: 0.2174
# Epoch 3/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.7225 - accuracy: 0.3571 - val_loss: 2.2366 - val_accuracy: 0.2609
# Epoch 4/20
# 56/56 [==============================] - 1s 24ms/step - loss: 1.6605 - accuracy: 0.3783 - val_loss: 2.2966 - val_accuracy: 0.3043
# Epoch 5/20
# 56/56 [==============================] - 1s 24ms/step - loss: 1.6531 - accuracy: 0.3945 - val_loss: 2.4863 - val_accuracy: 0.2174
# Epoch 6/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.6169 - accuracy: 0.4191 - val_loss: 2.5368 - val_accuracy: 0.2609
# Epoch 7/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.5826 - accuracy: 0.4297 - val_loss: 2.6465 - val_accuracy: 0.1304
# Epoch 8/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.5915 - accuracy: 0.4202 - val_loss: 2.3413 - val_accuracy: 0.3043
# Epoch 9/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.5374 - accuracy: 0.4526 - val_loss: 2.7297 - val_accuracy: 0.2174
# Epoch 10/20
# 56/56 [==============================] - 1s 24ms/step - loss: 1.5269 - accuracy: 0.4643 - val_loss: 2.1441 - val_accuracy: 0.3043
# Epoch 11/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.4479 - accuracy: 0.4900 - val_loss: 2.3615 - val_accuracy: 0.1739
# Epoch 12/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.4124 - accuracy: 0.5100 - val_loss: 2.4671 - val_accuracy: 0.2609
# Epoch 13/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.3843 - accuracy: 0.5123 - val_loss: 2.4332 - val_accuracy: 0.3043
# Epoch 14/20
# 56/56 [==============================] - 1s 24ms/step - loss: 1.3880 - accuracy: 0.5089 - val_loss: 2.7440 - val_accuracy: 0.2174
# Epoch 15/20
# 56/56 [==============================] - 1s 24ms/step - loss: 1.3725 - accuracy: 0.5151 - val_loss: 2.0309 - val_accuracy: 0.3043
# Epoch 16/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.3366 - accuracy: 0.5312 - val_loss: 2.3973 - val_accuracy: 0.3478
# Epoch 17/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.3614 - accuracy: 0.5134 - val_loss: 2.1578 - val_accuracy: 0.3478
# Epoch 18/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.3653 - accuracy: 0.5229 - val_loss: 2.0732 - val_accuracy: 0.3478
# Epoch 19/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.2977 - accuracy: 0.5335 - val_loss: 2.1281 - val_accuracy: 0.3043
# Epoch 20/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.3703 - accuracy: 0.5033 - val_loss: 2.6762 - val_accuracy: 0.3043

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# #### Distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
labels = {0 : "actinic", 1: "basel", 2: "dermatofibroma", 3: "melanoma", 4: "nevus",
          5: "pigmented", 6: "seborrheic", 7: "squamous", 8: "vascular"}

def get_classes_distribution(data):
    # Get the count for each label
    label_counts = data['label'].value_counts()

    # Get total number of samples
    total_samples = len(data)


    # Count the number of items in each class
    for i in range(len(label_counts)):
        label = labels[label_counts.index[i]]
        count = label_counts.values[i]
        percent = (count / total_samples) * 100
        print("{:<20s}:   {} or {}%".format(label, count, percent))

# %%
get_classes_distribution(train_df)
# Out:
# nevus               :   462 or 20.634211701652525%
# vascular            :   438 or 19.56230460026798%
# squamous            :   376 or 16.793211255024566%
# basel               :   357 or 15.944618133095132%
# seborrheic          :   181 or 8.083966056275123%
# pigmented           :   139 or 6.208128628852166%
# actinic             :   114 or 5.091558731576597%
# melanoma            :   95 or 4.242965609647164%
# dermatofibroma      :   77 or 3.439035283608754%

# %% [markdown]
# ####The Finding are as follows:
# #### - dermatofibroma class has least number of samples
# #### - nevus, vascular, squamous, basel classes dominate the data in terms proportionate number of samples

# %% [markdown]
# #### Rectify the class imbalance
# #### Using python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (8.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.65.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.22.4)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10),
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FDD3AC07E20>: 100%|██████████| 500/500 [00:11<00:00, 43.21 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FDDF86CFF40>: 100%|██████████| 500/500 [00:12<00:00, 38.61 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FDD3AC8FD30>: 100%|██████████| 500/500 [00:11<00:00, 45.13 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FDD3AC7D1E0>: 100%|██████████| 500/500 [00:55<00:00,  9.02 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FDD3AC66FB0>: 100%|██████████| 500/500 [00:46<00:00, 10.83 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FDD3ACE9AE0>: 100%|██████████| 500/500 [00:10<00:00, 45.78 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FDD3D48EA40>: 100%|██████████| 500/500 [00:22<00:00, 21.94 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FDD364269B0>: 100%|██████████| 500/500 [00:10<00:00, 46.16 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FDD3D72B640>: 100%|██████████| 500/500 [00:11<00:00, 45.11 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list_new
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029713.jpg_66f38969-6742-4d84-8155-8150541c1192.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029141.jpg_12f33ad3-90e7-44a1-afc5-4ad8ec8e0d86.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029500.jpg_292aa978-319b-4548-be24-4eda3635d90b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026525.jpg_30ec0539-8e12-41e2-8270-f7788389d956.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028558.jpg_e713f181-2dd9-4c61-86c7-ce5392c1f8b5.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030491.jpg_ad73d02e-38c6-4235-8ba8-0cb7944c3568.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030877.jpg_d1a051bb-34ae-4653-81c1-f2711cc6a038.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025825.jpg_86a84470-02a3-45ca-8603-1792f51d838b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031108.jpg_bdf460af-9d39-40c1-9c5a-b204d8b59630.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029133.jpg_09de8ae9-1e73-4d32-8773-4c003f5f7c1c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026857.jpg_5db1cb0e-05f5-4864-8cf3-67c6c71b43cb.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027668.jpg_9254849c-656d-4e98-95b1-f2fa79b694c2.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026194.jpg_7a6accdf-cf19-46a3-a09e-a97689e14ecd.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027896.jpg_88ba6dad-9606-4bac-bdb9-0b852a21d089.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027829.jpg_ae5bdf7f-5883-4285-bc4c-cae42ceeb3e6.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030344.jpg_0aaf0209-b28c-449d-b044-365323bdc355.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029827.jpg_2e5a7694-0728-4510-9049-b801d17eb2b3.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027668.jpg_47587102-8a8e-44b0-84c0-79d44dae199e.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029041.jpg_65adef8b-df64-4aec-96af-4230070bb3f0.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028990.jpg_a6a68db6-8f02-4942-84db-3f1eb70816cf.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032437.jpg_776260e2-9ec8-4dc7-b071-41a55146fddb.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028076.jpg_a8346343-688e-4957-9b41-8685620886bc.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032422.jpg_74b5f9f0-536a-43da-90fc-21f02bd4b1dc.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032437.jpg_14d4c884-d8fe-489c-ac81-cd7ca60a520a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029915.jpg_f983c7c0-3f7b-4099-9e7f-c8ddc2ee34fb.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026457.jpg_f4bcf98f-684f-4813-9848-37f2ff0d7a96.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030491.jpg_9ce711e0-76fb-41d1-8f40-3aab1a9241b0.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028190.jpg_be8dc031-b322-4718-bff1-b061b39e49e9.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027536.jpg_a1ee54e4-1175-4b6c-9085-b3a664521907.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029713.jpg_102481e7-85ae-4a26-a893-35b2ffbd7daa.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028990.jpg_f5341149-c84f-4665-a500-9530f2897141.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026729.jpg_e6c8aa0f-9fd6-4850-9cb4-1fcb08edd67b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031506.jpg_1eafa0dc-0832-411a-9a3d-e6dcbeadeb6a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031108.jpg_f491531d-ca77-4833-a903-41a3977cdec0.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031506.jpg_7fc58505-0b2d-46bd-9313-a56ddf054bd9.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026984.jpg_1ade3330-2680-49db-83f2-06986de12337.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026625.jpg_290efbf9-116d-43aa-a793-e95dc4ca5411.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031335.jpg_400cb3de-bb80-4b5b-9b46-2bdaeb027c93.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028063.jpg_63419250-418c-41a2-9a92-5ed0153c2dd2.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026525.jpg_9982804d-1de2-4719-a71e-c80d76c5bb67.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031609.jpg_2fa8b0fa-549b-4637-aabc-f5d07c63dec5.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030036.jpg_59f8a82b-cbe2-41a3-9cb2-ad877bbb335e.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026194.jpg_5ab32e31-78a2-41f4-a69a-026bb50c6233.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032199.jpg_3b97c3c5-f6e0-468f-a513-db040ab68c1e.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028517.jpg_a66ba984-72f4-4a50-9338-c937e5c0ccb3.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027562.jpg_bd2392c2-8199-4d7e-b78a-fb4be4a105bd.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026905.jpg_172cb92b-b901-49d2-888c-21c3d341129a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025992.jpg_2eeed4d6-ff86-4697-9623-2f3e2372b49a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028314.jpg_66625f8f-6511-40b3-af68-5deb608d5370.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029900.jpg_8784f1f4-97dd-4d8b-9ed8-41c3ec7621f1.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029210.jpg_a182c682-e5f7-4336-bdd6-70982130e618.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030344.jpg_e70aee44-510d-47a1-bdc3-24d33617dafa.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025780.jpg_5c201496-f894-4160-9ddd-f91808564420.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029500.jpg_d533c909-599d-4c69-acdb-f9efd5a02904.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027447.jpg_be602489-4cca-4315-aad3-737a037592c0.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028517.jpg_920aab04-9e57-4b9c-ac69-4652fb11bb0f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029915.jpg_0537e1cf-8994-4a96-baf3-68661c6b6c7b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028558.jpg_c1027340-b4a4-4f56-842b-cfe212e78d06.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031292.jpg_17efa72c-c02b-4458-a6bb-523614e5456f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030825.jpg_c66e5002-8d8e-4c01-94d7-3fda7800d926.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030344.jpg_1675ced7-9ee1-4563-985a-2ed8400d8eb2.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027884.jpg_7a70086d-43f5-49a4-8c2e-652a6d5b25b1.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029210.jpg_64ca76a3-bcde-47af-b6e8-e0aca9ead437.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030586.jpg_6daf3454-b16b-45d4-bce3-faec3fc77e0f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029827.jpg_e2e986d3-a489-4842-8665-bc8bb6941eb8.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028370.jpg_0c86dca1-d1d6-4072-9b08-55e6346404f3.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026194.jpg_98eda077-b331-4f96-ab8f-38c2c5996813.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029041.jpg_deb9a729-2f06-432c-a1d9-dbf4181374a0.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025825.jpg_dd3e3c83-4932-4522-aa1e-19a2ca8182fd.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027580.jpg_adb2b880-7634-484e-ac36-9547ec630db7.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031292.jpg_c31351fe-2ccd-42d4-8d7d-e1ca4f232ee3.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027536.jpg_71d45036-0731-48db-8797-57597a8528d0.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030143.jpg_529a2434-43d5-42df-b443-a9cfd1a93493.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032206.jpg_c235552a-130e-4e2b-9588-5baa340d96fc.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029781.jpg_8513c35b-e40c-461d-82af-024351eef293.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028076.jpg_3b58b3d3-0239-4152-9209-696fb5f65489.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031506.jpg_919ee890-c01d-4dbd-9e9a-3c47e25f615d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033811.jpg_cb21d7a9-a45e-417b-b839-619aeb129130.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027615.jpg_88403447-7450-4c85-97f8-db2063c1c320.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031292.jpg_507dcabc-3c73-4cbb-8fa0-481130ec2c40.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026857.jpg_63447155-e65f-4bca-a1f3-ce0992c9bcfd.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029133.jpg_cd3ab484-6ed4-45cb-8729-0d1492865363.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032437.jpg_2ffef9f2-a5b2-4e46-8af9-e045434295a0.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030408.jpg_9628882f-e822-4201-9573-06161fca7f2a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031335.jpg_2def8997-a6d0-4c3a-8aa7-feb317d2b8a9.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025957.jpg_8ba33b0b-f347-4dd4-b7a5-cee10ce40b44.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025992.jpg_f363e321-1da0-4aab-b6e6-9ecf4a57e9fa.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026984.jpg_a187c6da-78ef-4665-a538-82283971b83e.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028076.jpg_643ca679-2796-49ea-afaa-95b208a54165.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026848.jpg_926c9430-b480-4be7-a24e-c9afa4700593.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031292.jpg_d33e7e7c-54f0-45ef-9531-2bae5fc7b615.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028990.jpg_5df4e045-3316-4fb2-a6b8-defe096f93cc.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029915.jpg_fd81efb6-fe6a-44dd-9853-53af627757ea.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028063.jpg_6fc56c4a-c22b-4079-a65f-d0223253544f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028063.jpg_4f2c87d0-dda3-421a-b9b6-2a7c3d4b9f5b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030826.jpg_93339290-748d-4d92-93f2-9522a53b7f91.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030133.jpg_2ff6802e-ebf0-486a-8724-11c3866e1005.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028990.jpg_3be5d6b2-7552-4c71-8459-dc80617f18dc.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027650.jpg_2328556d-579a-436f-b4c1-9e10a4dc5ee3.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029930.jpg_a99f2728-0a62-43d5-9a79-afe8280b2e7f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029141.jpg_05c60f4d-eb84-4079-a2bd-ddb30c63d8ef.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030825.jpg_3d1889bb-e440-4130-8a91-541972c36243.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031430.jpg_22fa4bb2-72d0-442e-b781-2804c15a1030.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032404.jpg_f44d9717-5170-4fe4-8d04-f42b6e0144ea.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026709.jpg_c0155580-3b65-4f5f-a0e1-848250608207.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027334.jpg_2b489a9b-c274-4c1d-814a-69f134182ec3.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028063.jpg_537a274c-933c-4bc8-92ab-992ff5703ff4.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030730.jpg_c7a32b2e-7038-4b1a-bcae-8e138de1ef0f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027536.jpg_ea54c1ce-c237-4502-9cbe-0308faa865c5.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029915.jpg_a9e0d613-20af-479c-9976-1299bd93fada.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033358.jpg_f04442a8-beb4-40ad-b526-f9edb34be7ab.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025780.jpg_74d641a6-c27a-4528-b495-b4324c5a2442.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027562.jpg_1f169413-0d05-478b-9b23-8c0f4a432f67.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030133.jpg_7d985021-f20e-436a-8474-42f3543ac15e.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026212.jpg_d7f19db8-29b6-4b8a-a9ea-c0d4d960124e.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029827.jpg_dfd23ce7-41de-49f3-b7ba-7c3f7141cd52.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030242.jpg_75c58096-220d-494b-ae6e-a63c4fabde96.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026848.jpg_25c9bc7b-a18a-44c3-a135-adece228b711.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028558.jpg_c05953f4-2c57-4b2f-8666-1a1f018b1cc7.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027447.jpg_c29e365b-c0ce-4d66-a9b8-83c74ce8a5e3.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028558.jpg_f228b625-5e8e-4b66-82f5-661e38351815.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031228.jpg_ec90e1d2-01da-49a3-9f84-2a24a92321fa.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030586.jpg_6ac2d0c9-1cae-413e-8d25-6a494c9500c7.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026149.jpg_e232f017-622b-4a22-9231-98a293b5df84.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029659.jpg_cbbe4125-4514-44e1-8ec2-49d369d9328a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027668.jpg_dcb66659-3f95-4e20-9e9e-0f4fa31a77ad.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027536.jpg_bf78c053-e1e6-41a7-a8e9-2af36d178476.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030133.jpg_b031c8c2-4191-4a0c-b84e-4fb6a110aebd.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028558.jpg_712e2d58-4cfe-4dbd-ac7b-159320548d8f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029659.jpg_8ac1fdd4-6544-4fb8-b4a8-e647fcbe9ccd.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026212.jpg_2378dd24-201c-43fe-9af7-7d0df22c2f60.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027254.jpg_65f39d68-e584-4a92-85e0-0ef371a9e61b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031430.jpg_d600c2dd-1132-49a5-b3c0-73b45124672a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030491.jpg_c4b9526f-f275-47b7-8695-65134a3a3819.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026194.jpg_23797165-41a5-40f5-9e45-90d434f7963b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026149.jpg_d4afb334-4100-414d-8323-7ae9730b744a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027668.jpg_58d6f782-e3b6-432d-a3ee-4eec39214c05.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027172.jpg_a9a3bda1-af31-4cbf-8431-cf47811f56ed.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030586.jpg_e9cda4a8-8770-4bb8-9aae-9d6204483a5d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029900.jpg_ca6c0926-dff7-4681-8a95-1f191a53089e.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031430.jpg_7d763973-7baf-44c6-ad7e-692577580b9a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030826.jpg_09f17a7a-c077-4678-bed2-810a4ba6e55c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033151.jpg_6cc880d7-3535-45fe-974c-9626afc265c4.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031993.jpg_a7905a61-9c16-4d9f-b72c-65adf4104373.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030586.jpg_879fdaba-5dac-4daa-9808-458c251cf37c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033151.jpg_cdddd923-f598-4b86-8cb7-297917e2111f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029500.jpg_3ea016ba-d169-47e5-b8a4-3277d8fbe5dd.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032422.jpg_290c9203-2a14-43b3-b2a7-90d51edc81db.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026905.jpg_1a475cfa-451e-45da-8529-c36c61f59faa.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033151.jpg_91373fdb-9c33-4f7b-b62d-3cf3f5566781.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033866.jpg_a752aa32-82c4-4bb9-9929-55a1242e64fd.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029930.jpg_a5e6dfc2-6f7d-4fea-bc75-79d88381eb90.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032206.jpg_5e2f7bb9-9614-496d-ae76-529ae54e12b8.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026171.jpg_2eb89d95-0fd8-4a2f-bbf2-d48a7564618a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027829.jpg_b787dd03-bc54-4ae9-a051-754f85b0a9a6.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031335.jpg_ce760407-2ca6-4fc8-b493-02bf864fd516.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025957.jpg_64db6b9b-3061-4828-8abc-ae00781f03d3.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027650.jpg_f5929f56-0079-492f-9170-8c897164b7cc.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031506.jpg_fc340c3f-c471-4206-9f5a-c23cc22abf1f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026149.jpg_97256dad-38f8-40cb-a580-ae4f70ba5f7b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029025.jpg_1817c8be-17b1-44d3-8c62-9f9b528a929f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031506.jpg_5b7c2e24-4d76-49ce-8ba0-952f1e0e0f50.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026650.jpg_1fb4e146-f0c7-47d8-ae9f-f527b15a2ad7.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030655.jpg_14e6d00f-7378-45d6-a861-40ec81a6a0d1.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032854.jpg_6e8d3201-e6d3-43f8-93e0-6317aaf214b9.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030344.jpg_e49425c8-c2f7-4a64-a331-6f719d4c0a3b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029141.jpg_af6674ca-3fd8-4511-aeca-8b9cc985e859.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030242.jpg_daf5e6c9-9840-4c76-a200-57d4c6e47e00.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026457.jpg_0101b891-524d-415b-8e77-4e5209976ef5.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031292.jpg_702c029a-1214-4159-9adf-46d5cf41a030.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032135.jpg_19ef2cdd-937a-4366-a4f2-080eefdee720.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027580.jpg_3ef57f63-907b-429c-a6c7-b1dfd1e6fe56.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027452.jpg_da5228d4-4fda-468b-8e1a-127b478b0cda.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026575.jpg_1e28a8cc-197e-4076-a8a7-1c95a3f84593.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031430.jpg_5bda3b4a-fed3-4c64-8a4a-6f4989d5b8ca.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030655.jpg_bf338046-2ff1-41ad-82d1-64246c941667.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033413.jpg_df882a53-3b9e-4dae-8117-523948b9713c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027950.jpg_f7743f8b-fa36-4a95-b898-16bd00e4d784.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028393.jpg_b890db39-5702-4136-95cc-55232fca2403.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029210.jpg_44752247-fd3e-477f-8344-528fc5472d63.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029900.jpg_5dbde72d-a93b-4c3e-b991-c8094eee09e2.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027254.jpg_15ce355a-7aba-4bb9-a3a5-f84312cfc29d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027615.jpg_b21d5ce8-9f0e-426e-a605-814300a1095e.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026702.jpg_dfe3c88d-1c82-42ac-869f-d4971b563716.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029500.jpg_5d83276a-2dd1-4342-a0fe-06ab06421ca3.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029915.jpg_7d050845-0848-4e89-ae3a-cef4fd18a396.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029900.jpg_bc5ba5d8-d159-4a1f-b773-159d17cd820b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029041.jpg_e81f853f-dd24-436e-a78c-2b0a71f66e5d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027668.jpg_d1e892b2-5246-4aea-b126-7ccd7c75ea2d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027172.jpg_064847d4-df82-4c30-b667-64c3537d8db1.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028314.jpg_0477709d-b8a3-4136-a33d-65e5d94db9c9.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029210.jpg_990a2160-8313-4274-a1d1-4b37cb0ee42a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028941.jpg_a8b3c95e-8ee6-43e7-8e49-78a84bd5dd4b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029025.jpg_518be859-3610-4383-8fb3-4a30bbacdd51.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027172.jpg_a8a1af8e-e544-40f9-b97f-b41c84197747.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029460.jpg_1c88db75-0b68-4991-85e3-3a9b2f4313d9.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027334.jpg_0e0c7afb-f013-420e-b5e0-92b565cbfbfd.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028558.jpg_8a0f6ceb-b206-468c-a2be-e4f3dc3f8225.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029900.jpg_5d453978-3bc3-46a2-ab2c-979211a73dd3.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030344.jpg_586af42e-2854-4b2c-8181-470f4f1a54d7.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025957.jpg_0bbccc3c-0774-4493-b59c-ee2386cd7039.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026626.jpg_f41b043f-dcca-4da9-81b6-400c6c2f30c0.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027536.jpg_d7f7b2ae-4a75-4e0c-8ad5-3bf2f763bf57.jpg',
# ...
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0027829.jpg_a12fc8ae-c1cc-4e39-a9d8-a96255a5caef.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000535.jpg_dc49af9b-5732-4d43-9c67-c23ff03b22c6.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000539.jpg_9ecb6b1d-809b-44d4-a61d-030c32050700.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000050.jpg_a4347f8e-5c5f-4d03-8cf9-3e82b05aff7d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000508.jpg_d80633f5-b5f4-477c-999a-3786ab5bda02.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0027668.jpg_e96c3ac6-d5a2-403d-9f66-cd20c609c536.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000060.jpg_81b9033f-c30b-405c-b12b-e626ba21a5ad.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000229.jpg_c3db8d32-1c29-44e2-882f-b13381db599d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0024771.jpg_2be068dc-e0b5-470a-af4e-6d7ab4200d04.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0025803.jpg_9aad7c03-bdd6-4984-b419-223f42665f34.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0025957.jpg_86a26e04-d309-42bb-9ea3-75ed7687ad48.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000021.jpg_8343832a-4454-45c3-a546-d8cb9418d031.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000358.jpg_4d9d0116-f53c-4882-86b3-3b827b5e0d29.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000418.jpg_dc26291c-788a-435c-90a0-14c9d8612545.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000319.jpg_7a52ee98-de6f-4e24-913b-0cb6e7a0751f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000073.jpg_ddd6f85f-df01-45c5-9d7b-cd7b80c93b16.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0026626.jpg_f3ea6b11-68f2-4e62-916e-6593616b63b5.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0028990.jpg_0df2e33f-4a62-474c-98e1-766aee1c46c8.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000435.jpg_c26c96a3-f365-4698-a28f-f8d2c4ee78f1.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000057.jpg_66a8e750-c537-4379-9bbf-5c55de0896de.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000457.jpg_3369ed24-f853-451d-87a9-abea77d4641a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0026194.jpg_02b84f52-9155-405f-b531-758ecceb8f48.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000488.jpg_12a48937-9ae4-4720-a41e-a43b11b80ff6.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0024800.jpg_c7524937-42dd-4e8c-b141-7a575f29e51a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000073.jpg_3d7f33aa-3cea-4858-8389-6ed5d03cc84a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000316.jpg_f2ebe376-eb84-4adb-bb57-cae80aa256a4.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000535.jpg_d036500d-23ae-4ec6-948d-57d8c72ec93f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000067.jpg_9f966021-68aa-4da0-a116-9f9bb9b0a269.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000329.jpg_ddd7d018-2af0-4036-9c3f-ef96550bc87c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000471.jpg_40cb0779-1d4e-4b1c-ab88-a981c8f64f1a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000477.jpg_fb3340fe-06bc-4c55-81cf-e7468620cecb.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000442.jpg_72758c73-1a47-4935-b670-ebebccf83aee.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000460.jpg_e9da0ad7-adb4-4304-9fa1-bebb66465d1a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000443.jpg_fe38a590-70c7-41c6-a70e-dd80652c73d0.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0026984.jpg_00b9f2f8-9240-4cce-a90b-0bdff8e3a216.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000368.jpg_80728530-0415-4b85-9df9-1be0a7dec8a9.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000038.jpg_1bb63b92-f9d9-4cd4-9406-293f2c827bbb.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0029041.jpg_4e1ebab4-cd82-43b2-9672-d45dc61223d9.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000363.jpg_dae5cfa2-5c41-461c-b7bc-43635ee8c3cf.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000396.jpg_0812fafe-5c20-468b-9115-ef10ceac0961.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000273.jpg_b33b169a-d728-4c30-95b2-115a4958304b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000541.jpg_280c6105-0512-406a-85ce-6689cf76f96b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000323.jpg_4eb955ac-368d-4dd1-9f77-2b4192be49be.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000421.jpg_e7b33481-0232-41be-9f1a-4afb9f7b8789.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0024913.jpg_bceac4cf-3051-461f-b461-6b859fe779b8.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000370.jpg_bfe6cccd-5396-4cba-a3e3-269735e926b5.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000480.jpg_d0f988bc-7844-449b-a264-cc51f360b716.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000259.jpg_159515ad-cd0d-49a4-ad2b-a99ed7f08c0f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000084.jpg_11e30f12-91b9-4d8c-b106-27439f650606.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0029309.jpg_d999d25d-f0fb-44fa-860f-4b375dfaefca.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0028314.jpg_f999669d-679a-4d18-ba61-29be4f7d313c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000383.jpg_e00c2597-69e0-4eda-a18c-ff0c92d51b7f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000508.jpg_df0f1399-19fe-40e4-ab5f-a48a3e51b6b7.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000368.jpg_6af4525f-a6c7-4f29-bf38-5e11c7597091.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000407.jpg_1a50832b-cca4-4eee-b92c-a3604284e05e.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000476.jpg_269e9424-d6a4-4b54-888c-3cc1345d673d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000335.jpg_bd2e9739-d8e1-42a1-abc3-e2836b1a25f0.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000507.jpg_0e5a6177-bef6-4850-8012-e45230e982e4.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000233.jpg_8b39bbfb-1c52-4b8d-b5d3-ec704e29d701.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000051.jpg_0165de05-6b57-4561-8016-42f2944e1060.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0027536.jpg_63d90ab8-418d-4622-abad-04419548f485.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000509.jpg_e219bc4b-45ae-4c09-ad7a-4cf9eb2717ef.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000497.jpg_6bb0220b-567a-4cad-86ba-c8353729fa1f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000052.jpg_8e08574c-cb3d-4734-8384-45e7e1d48d32.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000523.jpg_fe2359ef-fa16-47ee-a595-ac82d7d99fdf.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000363.jpg_711a1851-c83d-47fd-b557-0dede7494683.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000223.jpg_15fc96a6-7dd1-4be9-8291-225950508442.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0025803.jpg_9d4d168b-963f-47b9-8971-4b391c2f6a12.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0029133.jpg_a1f33ff0-b00d-46c1-a26e-54d805b857b8.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0025825.jpg_60a2c8ec-45bb-485e-9c10-883d43db9928.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000256.jpg_324814d5-9109-48f6-992c-3264b2a75bed.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000544.jpg_ebe6d0d4-2e18-4fda-93ec-ba3aada9f541.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000386.jpg_0c58acf3-2fc2-4dc9-911c-35f2f61d1ea7.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000439.jpg_88637792-edf6-4989-8ab5-cbb0c5f40f9f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000425.jpg_0ed8ef8b-3dac-4ab5-811b-1943aef6b89d.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  ...]

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
path_list = [x for x in glob(os.path.join(data_dir_train,'*','*.jpg'))]

# %%
lesion_list = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train,'*','*.jpg'))]

# %%
dataframe_dict = dict(zip(path_list, lesion_list))

# %%
original_df = pd.DataFrame(list(dataframe_dict.items()),columns=['Path','Label'])

# %%
original_df['Label'].value_counts()
# Out:
# Train    2239
# Name: Label, dtype: int64

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)
# Out:
# <ipython-input-43-17a6b079869a>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = original_df.append(df2)

# %%
new_df['Label'].value_counts()
# Out:
# Train                         2239
# actinic keratosis              500
# nevus                          500
# seborrheic keratosis           500
# dermatofibroma                 500
# pigmented benign keratosis     500
# vascular lesion                500
# squamous cell carcinoma        500
# basal cell carcinoma           500
# melanoma                       500
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# ####  Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# ####  Create a training dataset

# %%
data_dir_train="/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "validation",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### Create model

# %%
## your code goes here
num_classes = 9
model = tf.keras.Sequential([
  layers.experimental.preprocessing.Rescaling(1.0/255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, (3, 3), padding="same", activation='relu'),
  layers.Conv2D(16, (3, 3), activation='relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Conv2D(32, (3, 3), padding="same", activation='relu'),
  layers.Conv2D(32, (3, 3), activation='relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Dropout(0.2),
  layers.Conv2D(64, (3, 3), padding="same", activation='relu'),
  layers.Conv2D(64, (3, 3), activation='relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Conv2D(128, (3, 3), activation='relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(256, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# #### Compile your model

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.build(input_shape=(None,180,180,3))
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_4 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_28 (Conv2D)          (None, 180, 180, 16)      448
#
#  conv2d_29 (Conv2D)          (None, 178, 178, 16)      2320
#
#  batch_normalization_8 (Batc  (None, 178, 178, 16)     64
#  hNormalization)
#
#  max_pooling2d_16 (MaxPoolin  (None, 89, 89, 16)       0
#  g2D)
#
#  conv2d_30 (Conv2D)          (None, 89, 89, 32)        4640
#
#  conv2d_31 (Conv2D)          (None, 87, 87, 32)        9248
#
#  batch_normalization_9 (Batc  (None, 87, 87, 32)       128
#  hNormalization)
#
#  max_pooling2d_17 (MaxPoolin  (None, 43, 43, 32)       0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 43, 43, 32)        0
#
#  conv2d_32 (Conv2D)          (None, 43, 43, 64)        18496
#
#  conv2d_33 (Conv2D)          (None, 41, 41, 64)        36928
#
#  batch_normalization_10 (Bat  (None, 41, 41, 64)       256
#  chNormalization)
#
#  max_pooling2d_18 (MaxPoolin  (None, 20, 20, 64)       0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 18, 18, 128)       73856
#
#  batch_normalization_11 (Bat  (None, 18, 18, 128)      512
#  chNormalization)
#
#  max_pooling2d_19 (MaxPoolin  (None, 9, 9, 128)        0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 9, 9, 128)         0
#
#  flatten_4 (Flatten)         (None, 10368)             0
#
#  dense_8 (Dense)             (None, 256)               2654464
#
#  dense_9 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 2,803,673
# Trainable params: 2,803,193
# Non-trainable params: 480
# _________________________________________________________________

# %% [markdown]
# ####  Train your model

# %%
epochs = 30
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 26s 124ms/step - loss: 2.2094 - accuracy: 0.4004 - val_loss: 4.0336 - val_accuracy: 0.0787
# Epoch 2/30
# 169/169 [==============================] - 23s 132ms/step - loss: 1.1521 - accuracy: 0.5851 - val_loss: 4.9477 - val_accuracy: 0.1418
# Epoch 3/30
# 169/169 [==============================] - 22s 126ms/step - loss: 0.8957 - accuracy: 0.6762 - val_loss: 2.7157 - val_accuracy: 0.3868
# Epoch 4/30
# 169/169 [==============================] - 22s 124ms/step - loss: 0.6415 - accuracy: 0.7776 - val_loss: 4.0098 - val_accuracy: 0.1477
# Epoch 5/30
# 169/169 [==============================] - 22s 126ms/step - loss: 0.4752 - accuracy: 0.8247 - val_loss: 2.2396 - val_accuracy: 0.4907
# Epoch 6/30
# 169/169 [==============================] - 21s 122ms/step - loss: 0.3817 - accuracy: 0.8546 - val_loss: 1.2026 - val_accuracy: 0.6451
# Epoch 7/30
# 169/169 [==============================] - 22s 124ms/step - loss: 0.3362 - accuracy: 0.8735 - val_loss: 0.9720 - val_accuracy: 0.6993
# Epoch 8/30
# 169/169 [==============================] - 22s 125ms/step - loss: 0.2602 - accuracy: 0.8974 - val_loss: 2.7453 - val_accuracy: 0.4566
# Epoch 9/30
# 169/169 [==============================] - 22s 126ms/step - loss: 0.3106 - accuracy: 0.8830 - val_loss: 5.5620 - val_accuracy: 0.2457
# Epoch 10/30
# 169/169 [==============================] - 21s 123ms/step - loss: 0.2710 - accuracy: 0.9000 - val_loss: 0.8749 - val_accuracy: 0.7253
# Epoch 11/30
# 169/169 [==============================] - 22s 127ms/step - loss: 0.2307 - accuracy: 0.9130 - val_loss: 0.6883 - val_accuracy: 0.7981
# Epoch 12/30
# 169/169 [==============================] - 22s 126ms/step - loss: 0.2050 - accuracy: 0.9204 - val_loss: 1.2337 - val_accuracy: 0.6808
# Epoch 13/30
# 169/169 [==============================] - 22s 123ms/step - loss: 0.1943 - accuracy: 0.9221 - val_loss: 5.0640 - val_accuracy: 0.3363
# Epoch 14/30
# 169/169 [==============================] - 22s 127ms/step - loss: 0.1898 - accuracy: 0.9266 - val_loss: 0.6778 - val_accuracy: 0.8010
# Epoch 15/30
# 169/169 [==============================] - 23s 129ms/step - loss: 0.1660 - accuracy: 0.9343 - val_loss: 0.8289 - val_accuracy: 0.7565
# Epoch 16/30
# 169/169 [==============================] - 22s 123ms/step - loss: 0.1444 - accuracy: 0.9407 - val_loss: 1.6426 - val_accuracy: 0.6385
# Epoch 17/30
# 169/169 [==============================] - 22s 127ms/step - loss: 0.1679 - accuracy: 0.9321 - val_loss: 1.9178 - val_accuracy: 0.6013
# Epoch 18/30
# 169/169 [==============================] - 21s 121ms/step - loss: 0.1836 - accuracy: 0.9240 - val_loss: 0.8689 - val_accuracy: 0.7275
# Epoch 19/30
# 169/169 [==============================] - 22s 127ms/step - loss: 0.2035 - accuracy: 0.9221 - val_loss: 5.5430 - val_accuracy: 0.3066
# Epoch 20/30
# 169/169 [==============================] - 22s 124ms/step - loss: 0.2594 - accuracy: 0.9063 - val_loss: 1.9105 - val_accuracy: 0.6184
# Epoch 21/30
# 169/169 [==============================] - 22s 126ms/step - loss: 0.1948 - accuracy: 0.9271 - val_loss: 0.8586 - val_accuracy: 0.7728
# Epoch 22/30
# 169/169 [==============================] - 22s 127ms/step - loss: 0.1471 - accuracy: 0.9401 - val_loss: 0.8990 - val_accuracy: 0.7491
# Epoch 23/30
# 169/169 [==============================] - 22s 125ms/step - loss: 0.1296 - accuracy: 0.9440 - val_loss: 0.9601 - val_accuracy: 0.7506
# Epoch 24/30
# 169/169 [==============================] - 22s 122ms/step - loss: 0.1311 - accuracy: 0.9468 - val_loss: 1.5727 - val_accuracy: 0.6696
# Epoch 25/30
# 169/169 [==============================] - 22s 125ms/step - loss: 0.1334 - accuracy: 0.9431 - val_loss: 6.5190 - val_accuracy: 0.2799
# Epoch 26/30
# 169/169 [==============================] - 21s 121ms/step - loss: 0.1373 - accuracy: 0.9431 - val_loss: 0.9669 - val_accuracy: 0.7847
# Epoch 27/30
# 169/169 [==============================] - 22s 126ms/step - loss: 0.1597 - accuracy: 0.9371 - val_loss: 2.3025 - val_accuracy: 0.5449
# Epoch 28/30
# 169/169 [==============================] - 22s 126ms/step - loss: 0.1830 - accuracy: 0.9323 - val_loss: 2.5612 - val_accuracy: 0.5516
# Epoch 29/30
# 169/169 [==============================] - 21s 120ms/step - loss: 0.1668 - accuracy: 0.9358 - val_loss: 2.4750 - val_accuracy: 0.5776
# Epoch 30/30
# 169/169 [==============================] - 22s 124ms/step - loss: 0.1223 - accuracy: 0.9477 - val_loss: 1.1044 - val_accuracy: 0.7402

# %% [markdown]
# #### Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?
